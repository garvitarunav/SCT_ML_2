# %% [markdown]
# ## Importing the DATA and essential libraries

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score, adjusted_rand_score, adjusted_mutual_info_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #### Some pre processing and Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# #### Visualizing the features to get an overview and checking whether there are outliers or not

# %%
data.hist(figsize = (12,8))
# Out:
# array([[<Axes: title={'center': 'CustomerID'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Annual Income (k$)'}>,
#         <Axes: title={'center': 'Spending Score (1-100)'}>]], dtype=object)

# %% [markdown]
# #### Segregating the Target Variable from the Input Features

# %%
target_var = data['CustomerID']

# %%
feature_var = data.drop('CustomerID', axis = 1)

# %%
feature_var.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
feature_var['Gender'] = feature_var['Gender'].replace('Male',0)
feature_var['Gender'] = feature_var['Gender'].replace('Female',1)

# %%
feature_var.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       0   19                  15                      39
# 1       0   21                  15                      81
# 2       1   20                  16                       6
# 3       1   23                  16                      77
# 4       1   31                  17                      40

# %% [markdown]
# #### Extracting the main input features and standardizing them using the standard scaler

# %%
x = feature_var[['Annual Income (k$)','Spending Score (1-100)']]

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# ### Using the Elbow Method for checking the optimal number of clusters

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# D:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# D:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# D:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# #### Visualizing the above for getting the best number of clusters

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# #### Training the data using the KMeans Algorithm

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=42)
y_kmeans = kmeans.fit_predict(x_scaled)
# Out:
# D:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data['Cluster'] = y_kmeans

# %% [markdown]
# #### Visualizing the Clusters

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=data, palette='viridis', s=100, alpha=0.7)
plt.title('Clusters of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Evaluation

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=42)
y_kmeans = kmeans.fit_predict(x_scaled)
# Out:
# D:\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
inertia = kmeans.inertia_
print(f"Inertia (WCSS): {inertia}")
# Out:
# Inertia (WCSS): 65.56840815571681

# %%
silhouette_avg = silhouette_score(x_scaled, y_kmeans)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.5546571631111091

# %%
davies_bouldin = davies_bouldin_score(x_scaled, y_kmeans)
print(f"Davies-Bouldin Index: {davies_bouldin}")
# Out:
# Davies-Bouldin Index: 0.5722356162263352

# %%
calinski_harabasz = calinski_harabasz_score(x_scaled, y_kmeans)
print(f"Calinski-Harabasz Index: {calinski_harabasz}")
# Out:
# Calinski-Harabasz Index: 248.64932001536357
